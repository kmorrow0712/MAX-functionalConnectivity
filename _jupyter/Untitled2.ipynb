# %%
from nistats.datasets import fetch_spm_auditory
subject_data = fetch_spm_auditory()
print(subject_data.func)
# Out:
# Dataset created in /Users/kellymorrow/nilearn_data/spm_auditory
#
# Data absent, downloading...
# Downloading data from http://www.fil.ion.ucl.ac.uk/spm/download/data/MoAEpilot/MoAEpilot.zip ...
# Downloaded 34212021 of 34212021 bytes (100.0%,    0.0s remaining) ...done. (3 seconds, 0 min)
# Extracting data from /Users/kellymorrow/nilearn_data/spm_auditory/sub001/MoAEpilot.zip..... done.

# %%
from nilearn.plotting import plot_stat_map, plot_anat, plot_img, show 
plot_img(subject_data.func[0])
plot_anat(subject_data.anat)

# %%
from nilearn.image import concat_imgs, mean_img
fmri_img = concat_imgs(subject_data.func)
mean_imag = mean_img(fmri_img)

# %%
import pandas as pd
events = pd.read_table(subject_data['events'])
print(events)
# Out:
#     onset  duration trial_type
# 0     0.0      42.0       rest
# 1    42.0      42.0     active
# 2    84.0      42.0       rest
# 3   126.0      42.0     active
# 4   168.0      42.0       rest
# 5   210.0      42.0     active
# 6   252.0      42.0       rest
# 7   294.0      42.0     active
# 8   336.0      42.0       rest
# 9   378.0      42.0     active
# 10  420.0      42.0       rest
# 11  462.0      42.0     active
# 12  504.0      42.0       rest
# 13  546.0      42.0     active
# 14  588.0      42.0       rest
# 15  630.0      42.0     active

# %%
from nistats.first_level_model import FirstLevelModel
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-c1431fa72949> in <module>
# ----> 1 from nistats.first_level_model import FirstLevelModel
#
# ~/.local/lib/python3.7/site-packages/nistats/first_level_model.py in <module>
#      25                           TransformerMixin,
#      26                           )
# ---> 27 from sklearn.externals.joblib import Memory
#      28 from nilearn.input_data import NiftiMasker
#      29 from nilearn._utils import CacheMixin
#
# ModuleNotFoundError: No module named 'sklearn.externals.joblib'
